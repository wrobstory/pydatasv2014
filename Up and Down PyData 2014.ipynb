# %% [markdown]
# # Up and Down the Python Data and Web Visualization Stack

# %% [markdown]
# USGS dataset listing every wind turbine in the United States:

# %%
import pandas as pd
import numpy as np
import vincent
import mpld3
import matplotlib.pyplot as plt
from ggplot import *

# %matplotlib inline
mpld3.enable_notebook()
vincent.initialize_notebook()

df = pd.read_csv('USGS_WindTurbine_201307_cleaned.csv')
df.head()
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('loading all libs')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://trifacta.github.com/vega/vega.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>
#    Unnamed: 0  Unique ID        Site Name Online Year Turbine Manufacturer  \
# 0           0       1836       Sand Point        2012               Vestas
# 1           1       1837       Sand Point        2012               Vestas
# 2           2       1838  St. Paul Island        2007               Vestas
# 3           3       1839  St. Paul Island        1999               Vestas
# 4           4       1840  St. Paul Island        2007               Vestas
#
#   Turbine Model Tower Type  Turbine MW  Total Height  Tower/Hub Height  \
# 0           V39   monopole       0.500          59.5                40
# 1           V39   monopole       0.500          59.5                40
# 2           V27   monopole       0.225          50.5                37
# 3           V27   monopole       0.225          50.5                37
# 4           V27   monopole       0.225          50.5                37
#
#    Blade Length  Rotor Diameter  Rotor Swept Area  Latitude-Decimal Degrees  \
# 0          19.5              39           1194.59                   55.3436
# 1          19.5              39           1194.59                   55.3448
# 2          13.5              27            572.55                   57.1571
# 3          13.5              27            572.55                   57.1576
# 4          13.5              27            572.55                   57.1576
#
#    Longitude-Decimal Degrees State          County  Attribute Confidence  \
# 0                  -160.4891    AK  Aleutians East                     2
# 1                  -160.4906    AK  Aleutians East                     2
# 2                  -170.2352    AK  Aleutians West                     2
# 3                  -170.2359    AK  Aleutians West                     2
# 4                  -170.2373    AK  Aleutians West                     2
#
#    Location Confidence  WENDI Site Name
# 0                    2          unknown ...
# 1                    2          unknown ...
# 2                    2  St. Paul Island ...
# 3                    2  St. Paul Island ...
# 4                    2  St. Paul Island ...
#
# [5 rows x 27 columns]

# %%
# Rotor Diameter vs. Turbine Manufacturer
mf_grouped = df.groupby('Turbine Manufacturer')
mean_rd = mf_grouped.mean().dropna().sort('Rotor Diameter')['Rotor Diameter']
rotor_diam = vincent.Bar(mean_rd)
rotor_diam.axis_titles(x='Turbine Manufacturer', y='Rotor Diameter')
# The Hard Way
from vincent.axes import AxisProperties
from vincent.properties import PropertySet
from vincent.values import ValueRef
for axis in rotor_diam.axes:
    axis.properties = AxisProperties()
    for prop in ['ticks', 'axis', 'major_ticks', 'minor_ticks']:
        setattr(axis.properties, prop, PropertySet(stroke=ValueRef(value='#d0d0d0')))
    axis.properties.title = PropertySet(font_size=ValueRef(value=20), 
                                        fill=ValueRef(value='#d0d0d0'))
    axis.properties.labels = PropertySet(fill=ValueRef(value='#d0d0d0'))
rotor_diam.axes[0].properties.labels.angle = ValueRef(value=50)
rotor_diam.axes[0].properties.labels.align = ValueRef(value='left')
rotor_diam.axes[0].properties.title.dy = ValueRef(value=115)
rotor_diam.scales[2].range = ['#b48ead']
rotor_diam
# Out:
# <div id="vis3aea280fb5174a6a839892000ccb75dc"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"axis": {"stroke": {"value": "#d0d0d0"}}, "labels": {"align": {"value": "left"}, "angle": {"value": 50}, "fill": {"value": "#d0d0d0"}}, "majorTicks": {"stroke": {"value": "#d0d0d0"}}, "minorTicks": {"stroke": {"value": "#d0d0d0"}}, "title": {"dy": {"value": 115}, "fill": {"value": "#d0d0d0"}, "fontSize": {"value": 20}}}, "scale": "x", "title": "Turbine Manufacturer", "type": "x"}, {"properties": {"axis": {"stroke": {"value": "#d0d0d0"}}, "labels": {"fill": {"value": "#d0d0d0"}}, "majorTicks": {"stroke": {"value": "#d0d0d0"}}, "minorTicks": {"stroke": {"value": "#d0d0d0"}}, "title": {"fill": {"value": "#d0d0d0"}, "fontSize": {"value": 20}}}, "scale": "y", "title": "Rotor Diameter", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Rotor Diameter", "idx": "Evance", "val": 5.5}, {"col": "Rotor Diameter", "idx": "Windmatic", "val": 15.734375}, {"col": "Rotor Diameter", "idx": "Nordtank", "val": 16.0}, {"col": "Rotor Diameter", "idx": "Kenetech", "val": 17.470588235294116}, {"col": "Rotor Diameter", "idx": "Entegrity", "val": 18.714285714285715}, {"col": "Rotor Diameter", "idx": "Northern Power Systems", "val": 20.966666666666665}, {"col": "Rotor Diameter", "idx": "Windmaster", "val": 22.0}, {"col": "Rotor Diameter", "idx": "Turbowind", "val": 34.0}, {"col": "Rotor Diameter", "idx": "unknown", "val": 36.2}, {"col": "Rotor Diameter", "idx": "Bonus", "val": 39.21176470588235}, {"col": "Rotor Diameter", "idx": "NEG Micon", "val": 44.87551020408172}, {"col": "Rotor Diameter", "idx": "Tacke", "val": 46.0}, {"col": "Rotor Diameter", "idx": "UMPI", "val": 47.0}, {"col": "Rotor Diameter", "idx": "Elecon", "val": 48.0}, {"col": "Rotor Diameter", "idx": "Zond", "val": 49.78087649402391}, {"col": "Rotor Diameter", "idx": "Enron", "val": 50.264150943396224}, {"col": "Rotor Diameter", "idx": "Aeronautica", "val": 52.25}, {"col": "Rotor Diameter", "idx": "Emergya Wind Technologies", "val": 53.0}, {"col": "Rotor Diameter", "idx": "AWE", "val": 53.0}, {"col": "Rotor Diameter", "idx": "EWT", "val": 54.0}, {"col": "Rotor Diameter", "idx": "BHD", "val": 55.0}, {"col": "Rotor Diameter", "idx": "PowerWind", "val": 56.0}, {"col": "Rotor Diameter", "idx": "Nordic", "val": 56.5}, {"col": "Rotor Diameter", "idx": "Unison", "val": 57.0}, {"col": "Rotor Diameter", "idx": "Mitsubishi", "val": 66.99889502762257}, {"col": "Rotor Diameter", "idx": "Vestas", "val": 68.62922140782759}, {"col": "Rotor Diameter", "idx": "Vensys", "val": 74.8}, {"col": "Rotor Diameter", "idx": "Leitwind", "val": 76.6}, {"col": "Rotor Diameter", "idx": "AAER", "val": 77.0}, {"col": "Rotor Diameter", "idx": "Acciona", "val": 79.8955223880597}, {"col": "Rotor Diameter", "idx": "GE", "val": 80.35905532530755}, {"col": "Rotor Diameter", "idx": "Hyundai Heavy Industries", "val": 81.5}, {"col": "Rotor Diameter", "idx": "Sinovel", "val": 82.0}, {"col": "Rotor Diameter", "idx": "Goldwind", "val": 84.72727272727273}, {"col": "Rotor Diameter", "idx": "Suzlon", "val": 85.80982073265783}, {"col": "Rotor Diameter", "idx": "Gamesa", "val": 85.98375350140056}, {"col": "Rotor Diameter", "idx": "ECO", "val": 86.0}, {"col": "Rotor Diameter", "idx": "Alstrom", "val": 86.08}, {"col": "Rotor Diameter", "idx": "Sany", "val": 88.0}, {"col": "Rotor Diameter", "idx": "DeWind", "val": 89.39759036144578}, {"col": "Rotor Diameter", "idx": "Samsung", "val": 90.0}, {"col": "Rotor Diameter", "idx": "Fuhrlander", "val": 90.0}, {"col": "Rotor Diameter", "idx": "REpower", "val": 92.5}, {"col": "Rotor Diameter", "idx": "HZ Windpower", "val": 92.8}, {"col": "Rotor Diameter", "idx": "Nordex", "val": 95.8069498069496}, {"col": "Rotor Diameter", "idx": "Clipper", "val": 96.32988165680473}, {"col": "Rotor Diameter", "idx": "Siemens", "val": 97.43130118289353}, {"col": "Rotor Diameter", "idx": "Kenersys", "val": 100.0}, {"col": "Rotor Diameter", "idx": "China Creative Wind", "val": 116.0}]}, {"name": "stats", "source": "table", "transform": [{"keys": ["data.idx"], "t ...
#          chart({el: "#vis3aea280fb5174a6a839892000ccb75dc"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
# Total Turbine Count
turbine_ct = mf_grouped.count().dropna().sort('Unique ID', ascending=False)['Unique ID']
num_turbines = vincent.Bar(turbine_ct[:25])
num_turbines.axis_titles(x='Turbine Manufacturer', y='Number of Turbines in the US')
num_turbines.colors(range_=['#6a9fb5'])
# Shortcuts!
def lighten_axes(vis, x_offset=50):
    # Make this 
    vis.common_axis_properties(color='#d0d0d0', title_size=20)
    vis.x_axis_properties(label_angle=50, label_align='left', title_offset=x_offset)
    vis.y_axis_properties(title_offset=-40)
# If Area Chart
# num_turbines.scales[0].type = 'ordinal'
lighten_axes(num_turbines)
num_turbines
# Out:
# <div id="vis378e2e4ed0bd4710b4dd0cba77c03fcd"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"axis": {"stroke": {"value": "#d0d0d0"}}, "labels": {"align": {"value": "left"}, "angle": {"value": 50}, "fill": {"value": "#d0d0d0"}}, "majorTicks": {"stroke": {"value": "#d0d0d0"}}, "minorTicks": {"stroke": {"value": "#d0d0d0"}}, "title": {"dy": {"value": 50}, "fill": {"value": "#d0d0d0"}, "fontSize": {"value": 20}}}, "scale": "x", "title": "Turbine Manufacturer", "type": "x"}, {"properties": {"axis": {"stroke": {"value": "#d0d0d0"}}, "labels": {"fill": {"value": "#d0d0d0"}}, "majorTicks": {"stroke": {"value": "#d0d0d0"}}, "minorTicks": {"stroke": {"value": "#d0d0d0"}}, "title": {"dy": {"value": -40}, "fill": {"value": "#d0d0d0"}, "fontSize": {"value": 20}}}, "scale": "y", "title": "Number of Turbines in the US", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Unique ID", "idx": "GE", "val": 15343}, {"col": "Unique ID", "idx": "Vestas", "val": 7263}, {"col": "Unique ID", "idx": "unknown", "val": 6469}, {"col": "Unique ID", "idx": "Kenetech", "val": 3808}, {"col": "Unique ID", "idx": "Siemens", "val": 3384}, {"col": "Unique ID", "idx": "Mitsubishi", "val": 2844}, {"col": "Unique ID", "idx": "Gamesa", "val": 1987}, {"col": "Unique ID", "idx": "Suzlon", "val": 1294}, {"col": "Unique ID", "idx": "NEG Micon", "val": 790}, {"col": "Unique ID", "idx": "Bonus", "val": 732}, {"col": "Unique ID", "idx": "Clipper", "val": 676}, {"col": "Unique ID", "idx": "REpower", "val": 614}, {"col": "Unique ID", "idx": "Acciona", "val": 603}, {"col": "Unique ID", "idx": "Zond", "val": 530}, {"col": "Unique ID", "idx": "Nordtank", "val": 308}, {"col": "Unique ID", "idx": "Nordex", "val": 259}, {"col": "Unique ID", "idx": "Enron", "val": 159}, {"col": "Unique ID", "idx": "Danwin", "val": 144}, {"col": "Unique ID", "idx": "Enertech", "val": 136}, {"col": "Unique ID", "idx": "Howden", "val": 96}, {"col": "Unique ID", "idx": "Goldwind", "val": 93}, {"col": "Unique ID", "idx": "DeWind", "val": 83}, {"col": "Unique ID", "idx": "Northern Power Systems", "val": 58}, {"col": "Unique ID", "idx": "Windmatic", "val": 50}, {"col": "Unique ID", "idx": "Alstrom", "val": 25}]}, {"name": "stats", "source": "table", "transform": [{"keys": ["data.idx"], "type": "facet"}, {"type": "stats", "value": "data.val"}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table", "transform": [{"keys": ["data.col"], "type": "facet"}, {"height": "data.val", "point": "data.idx", "type": "stack"}]}, "marks": [{"properties": {"enter": {"fill": {"field": "data.col", "scale": "color"}, "width": {"band": true, "offset": -1, "scale": "x"}, "x": {"field": "data.idx", "scale": "x"}, "y": {"field": "y", "scale": "y"}, "y2": {"field": "y2", "scale": "y"}}}, "type": "rect"}], "type": "group"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "x", "range": "width", "type": "ordinal", "zero": false}, {"domain": {"data": "stats", "field": "sum"}, "name": "y", "nice": true, "range": "height"}, {"domain": {"data": "table", "field": "data.col"}, "name": "color", "range": ["#6a9fb5"], "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis378e2e4ed0bd4710b4dd0cba77c03fcd"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
# Turbine Count vs. Date
grouped_date = df.groupby(['Online Year', 'Turbine Manufacturer'])
by_year = grouped_date.count()['Unique ID'].reset_index()
by_year['Online Year'] = pd.to_datetime(by_year['Online Year'], coerce=True)
by_year = by_year.rename(columns={'Unique ID': 'Turbine Count'}).dropna()
by_year = by_year.pivot(index='Online Year', columns='Turbine Manufacturer', values='Turbine Count')
by_year = by_year[turbine_ct[:10].index.tolist()]

online_by_year = vincent.StackedArea(by_year)
online_by_year.axis_titles(x='Date', y='Turbine Count')
online_by_year.legend(title='Turbine Manufacturer', text_color='#d0d0d0')
online_by_year.colors(range_=['#ac4142', '#d28445', '#f4bf75', '#90a959', 
                              '#75b5aa', '#6a9fb5', '#aa759f', '#8f5536'])
lighten_axes(online_by_year, x_offset=30)
online_by_year
# Out:
# <div id="vis7858186c29a847b3bf90119a0956148d"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"axis": {"stroke": {"value": "#d0d0d0"}}, "labels": {"align": {"value": "left"}, "angle": {"value": 50}, "fill": {"value": "#d0d0d0"}}, "majorTicks": {"stroke": {"value": "#d0d0d0"}}, "minorTicks": {"stroke": {"value": "#d0d0d0"}}, "title": {"dy": {"value": 30}, "fill": {"value": "#d0d0d0"}, "fontSize": {"value": 20}}}, "scale": "x", "title": "Date", "type": "x"}, {"properties": {"axis": {"stroke": {"value": "#d0d0d0"}}, "labels": {"fill": {"value": "#d0d0d0"}}, "majorTicks": {"stroke": {"value": "#d0d0d0"}}, "minorTicks": {"stroke": {"value": "#d0d0d0"}}, "title": {"dy": {"value": -40}, "fill": {"value": "#d0d0d0"}, "fontSize": {"value": 20}}}, "scale": "y", "title": "Turbine Count", "type": "y"}], "data": [{"name": "table", "values": [{"col": "GE", "idx": 347184000000, "val": NaN}, {"col": "Vestas", "idx": 347184000000, "val": NaN}, {"col": "unknown", "idx": 347184000000, "val": NaN}, {"col": "Kenetech", "idx": 347184000000, "val": NaN}, {"col": "Siemens", "idx": 347184000000, "val": NaN}, {"col": "Mitsubishi", "idx": 347184000000, "val": NaN}, {"col": "Gamesa", "idx": 347184000000, "val": NaN}, {"col": "Suzlon", "idx": 347184000000, "val": NaN}, {"col": "NEG Micon", "idx": 347184000000, "val": NaN}, {"col": "Bonus", "idx": 347184000000, "val": NaN}, {"col": "GE", "idx": 378720000000, "val": NaN}, {"col": "Vestas", "idx": 378720000000, "val": NaN}, {"col": "unknown", "idx": 378720000000, "val": 1.0}, {"col": "Kenetech", "idx": 378720000000, "val": NaN}, {"col": "Siemens", "idx": 378720000000, "val": NaN}, {"col": "Mitsubishi", "idx": 378720000000, "val": NaN}, {"col": "Gamesa", "idx": 378720000000, "val": NaN}, {"col": "Suzlon", "idx": 378720000000, "val": NaN}, {"col": "NEG Micon", "idx": 378720000000, "val": NaN}, {"col": "Bonus", "idx": 378720000000, "val": NaN}, {"col": "GE", "idx": 441792000000, "val": NaN}, {"col": "Vestas", "idx": 441792000000, "val": 453.0}, {"col": "unknown", "idx": 441792000000, "val": NaN}, {"col": "Kenetech", "idx": 441792000000, "val": NaN}, {"col": "Siemens", "idx": 441792000000, "val": NaN}, {"col": "Mitsubishi", "idx": 441792000000, "val": NaN}, {"col": "Gamesa", "idx": 441792000000, "val": NaN}, {"col": "Suzlon", "idx": 441792000000, "val": NaN}, {"col": "NEG Micon", "idx": 441792000000, "val": NaN}, {"col": "Bonus", "idx": 441792000000, "val": NaN}, {"col": "GE", "idx": 473414400000, "val": NaN}, {"col": "Vestas", "idx": 473414400000, "val": NaN}, {"col": "unknown", "idx": 473414400000, "val": 387.0}, {"col": "Kenetech", "idx": 473414400000, "val": NaN}, {"col": "Siemens", "idx": 473414400000, "val": NaN}, {"col": "Mitsubishi", "idx": 473414400000, "val": NaN}, {"col": "Gamesa", "idx": 473414400000, "val": NaN}, {"col": "Suzlon", "idx": 473414400000, "val": NaN}, {"col": "NEG Micon", "idx": 473414400000, "val": NaN}, {"col": "Bonus", "idx": 473414400000, "val": 210.0}, {"col": "GE", "idx": 504950400000, "val": NaN}, {"col": "Vestas", "idx": 504950400000, "val": 200.0}, {"col": "unknown", "idx": 504950400000, "val": 39.0}, {"col": "Kenetech", "idx": 504950400000, "val": NaN}, {"col": "Siemens", "idx": 504950400000, "val": NaN}, {"col": "Mitsubishi", "idx": 504950400000, "val": NaN}, {"col": "Gamesa", "idx": 504950400000, "val": NaN}, {"col": "Suzlon", "idx": 504950400000, "val": NaN}, {"col": "NEG Micon", "idx": 504950400000, "val": NaN}, {"col": "Bonus", "idx": 504950400000, "val": NaN}, {"col": "GE", "idx": 536486400000, "val": NaN}, {"col": "Vestas", "idx": 536486400000, "val": NaN}, {"col": "unknown", "idx": 536486400000, "val": NaN}, {"col": "Kenetech", "idx": 536486400000, "val": NaN}, {"col": "Siemens", "idx": 536486400000, "val": NaN}, {"col": "Mitsubishi", "idx": 536486400000, "val": 37.0}, {"col": "Gamesa", "idx": 536486400000, "val": NaN}, {"col": "Suzlon", "idx": 536486400000, "val": NaN}, {"col": "NEG Micon", "idx": 536486400000, "val": NaN}, {"col": "Bonus", "idx": 536486400000, "val": NaN}, {"col": "GE", "idx": 568022400000, "val" ...

# %%
# Rotor Diameter vs. Power
min_heights = df[df['Rotor Diameter'] > 10]
diameter_vs_mw = vincent.Scatter(min_heights[['Turbine MW', 'Rotor Diameter']], iter_idx='Turbine MW')
diameter_vs_mw.axis_titles(x='Power (MW)', y='Rotor Diameter (m)')
diameter_vs_mw.colors(range_=['#75b5aa'])
lighten_axes(diameter_vs_mw, x_offset=30)
diameter_vs_mw
# Out:
# <div id="vise991ac2bf47b444eb13a6f27ab1786d1"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"axis": {"stroke": {"value": "#d0d0d0"}}, "labels": {"align": {"value": "left"}, "angle": {"value": 50}, "fill": {"value": "#d0d0d0"}}, "majorTicks": {"stroke": {"value": "#d0d0d0"}}, "minorTicks": {"stroke": {"value": "#d0d0d0"}}, "title": {"dy": {"value": 30}, "fill": {"value": "#d0d0d0"}, "fontSize": {"value": 20}}}, "scale": "x", "title": "Power (MW)", "type": "x"}, {"properties": {"axis": {"stroke": {"value": "#d0d0d0"}}, "labels": {"fill": {"value": "#d0d0d0"}}, "majorTicks": {"stroke": {"value": "#d0d0d0"}}, "minorTicks": {"stroke": {"value": "#d0d0d0"}}, "title": {"dy": {"value": -40}, "fill": {"value": "#d0d0d0"}, "fontSize": {"value": 20}}}, "scale": "y", "title": "Rotor Diameter (m)", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Rotor Diameter", "idx": 0.5, "val": 39.0}, {"col": "Rotor Diameter", "idx": 0.5, "val": 39.0}, {"col": "Rotor Diameter", "idx": 0.22500000000000001, "val": 27.0}, {"col": "Rotor Diameter", "idx": 0.22500000000000001, "val": 27.0}, {"col": "Rotor Diameter", "idx": 0.22500000000000001, "val": 27.0}, {"col": "Rotor Diameter", "idx": 1.5, "val": 77.0}, {"col": "Rotor Diameter", "idx": 1.5, "val": 77.0}, {"col": "Rotor Diameter", "idx": 1.5, "val": 77.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.095000000000000001, "val": 17.0}, {"col": "Rotor Diameter", "idx": 0.095000000000000001, "val": 17.0}, {"col": "Rotor Diameter", "idx": 0.095000000000000001, "val": 17.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 1.6000000000000001, "val": 82.5}, {"col": "Rotor Diameter", "idx": 1.6000000000000001, "val": 82.5}, {"col": "Rotor Diameter", "idx": 1.6000000000000001, "val": 82.5}, {"col": "Rotor Diameter", "idx": 1.6000000000000001, "val": 82.5}, {"col": "Rotor Diameter", "idx": 1.6000000000000001, "val": 82.5}, {"col": "Rotor Diameter", "idx": 1.6000000000000001, "val": 82.5}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.90000000000000002, "val": 54.0}, {"col": "Rotor Diameter", "idx": 2.0499999999999998, "val": 92.5}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.10000000000000001, "val": 21.0}, {"col": "Rotor Diameter", "idx": 0.050000000000000003, "val": 15.0}, {"col": "Rotor ...

# %%
(ggplot(aes(x='Turbine MW', y='Rotor Swept Area'), data=min_heights[:500])
        + geom_point(color='#75b5aa', size=75)
        + ggtitle("Rotor Swept Area vs. Power")
        + xlab("Power (MW)")
        + ylab("Rotor Swept Area (m^2)"))
# Out:
# <ggplot: (289145249)>

# %%
import seaborn as sb
sb.set(rc={'text.color': '#d0d0d0', 'axes.labelcolor': '#d0d0d0'})
rvm = df[['Rotor Diameter', 'Turbine MW', 'Turbine Manufacturer']].dropna()
row_mask = rvm['Turbine Manufacturer'].isin(['Vestas', 'Siemens', 'GE'])
rvm = rvm[row_mask]
rvm['Rotor Diameter'] = rvm['Rotor Diameter'].apply(lambda x: int(5 * round(float(x)/5)))
grouped_rvm = rvm.groupby(['Rotor Diameter', 'Turbine Manufacturer'])
rvm = grouped_rvm.mean().reset_index()
sb.lmplot("Rotor Diameter", "Turbine MW", col="Turbine Manufacturer", 
          hue="Turbine Manufacturer", data=rvm)

# %%
ws = pd.read_table('CO_WS_2011_2012.txt')
ws = ws.set_index('Date & Time Stamp')
ws.index = ws.index.to_datetime()
ws.head()
# Out:
#                      WS1_50mMean  WS1_50mStdev  WS1_50mMax  WS1_50mMin  \
# 2011-06-03 00:00:00         9.50          1.12       11.70        6.40
# 2011-06-03 00:10:00         8.37          0.56       10.19        6.78
# 2011-06-03 00:20:00         8.38          0.43        9.44        7.17
# 2011-06-03 00:30:00         7.48          1.17        9.44        3.76
# 2011-06-03 00:40:00         7.13          0.79        9.06        5.26
#
#                      WS2_50mMean  WS2_50mStDev  WS2_50mMax  WS2_50mMin  \
# 2011-06-03 00:00:00         9.39          1.03       11.39        6.43
# 2011-06-03 00:10:00         8.27          0.56        9.86        6.43
# 2011-06-03 00:20:00         8.28          0.41        9.48        7.20
# 2011-06-03 00:30:00         7.43          1.12        9.48        3.77
# 2011-06-03 00:40:00         7.10          0.76        9.09        5.28
#
#                      WS3_30mMean  WS3_30mStDev  WS3_30mMax  WS3_30mMin  \
# 2011-06-03 00:00:00         7.96          1.33       10.97        4.51
# 2011-06-03 00:10:00         6.83          0.76        9.06        3.75
# 2011-06-03 00:20:00         7.13          0.64        8.69        4.89
# 2011-06-03 00:30:00         6.43          1.03        8.29        3.37
# 2011-06-03 00:40:00         6.21          0.67        7.91        2.99
#
#                      WS4_40mMean  WS4_40mStDev  WS4_40mMax  WS4_40mMin  \
# 2011-06-03 00:00:00         8.76          1.17       11.01        4.95
# 2011-06-03 00:10:00         7.60          0.64        9.49        5.70
# 2011-06-03 00:20:00         7.81          0.45        9.10        6.83
# 2011-06-03 00:30:00         6.93          1.03        9.10        3.43
# 2011-06-03 00:40:00         6.61          0.66        8.34        3.81
#
#                      WD1_49mMean  WD1_49mStDev  WD1_49mMax  WD1_49mMin
# 2011-06-03 00:00:00          172             7         173         240 ...
# 2011-06-03 00:10:00          172             5         169         240 ...
# 2011-06-03 00:20:00          169             5         177         240 ...
# 2011-06-03 00:30:00          163            11         166         240 ...
# 2011-06-03 00:40:00          172            12         166         240 ...
#
# [5 rows x 24 columns]

# %%
november_2011 = ws['2011-11-15':'2011-12-01']
ws_line = vincent.Line(november_2011['WS1_50mMean'])
ws_line.axis_titles(x='Date', y='Wind Speed (m/s)')
ws_line.colors(range_=['#d28445'])
lighten_axes(ws_line, x_offset=30)
ws_line
# Out:
# <div id="vis14886f1ad4d1476bae2bcf16152b6a9c"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"properties": {"axis": {"stroke": {"value": "#d0d0d0"}}, "labels": {"align": {"value": "left"}, "angle": {"value": 50}, "fill": {"value": "#d0d0d0"}}, "majorTicks": {"stroke": {"value": "#d0d0d0"}}, "minorTicks": {"stroke": {"value": "#d0d0d0"}}, "title": {"dy": {"value": 30}, "fill": {"value": "#d0d0d0"}, "fontSize": {"value": 20}}}, "scale": "x", "title": "Date", "type": "x"}, {"properties": {"axis": {"stroke": {"value": "#d0d0d0"}}, "labels": {"fill": {"value": "#d0d0d0"}}, "majorTicks": {"stroke": {"value": "#d0d0d0"}}, "minorTicks": {"stroke": {"value": "#d0d0d0"}}, "title": {"dy": {"value": -40}, "fill": {"value": "#d0d0d0"}, "fontSize": {"value": 20}}}, "scale": "y", "title": "Wind Speed (m/s)", "type": "y"}], "data": [{"name": "table", "values": [{"col": "WS1_50mMean", "idx": 1321344000000, "val": 13.24}, {"col": "WS1_50mMean", "idx": 1321344600000, "val": 14.41}, {"col": "WS1_50mMean", "idx": 1321345200000, "val": 11.49}, {"col": "WS1_50mMean", "idx": 1321345800000, "val": 11.33}, {"col": "WS1_50mMean", "idx": 1321346400000, "val": 16.16}, {"col": "WS1_50mMean", "idx": 1321347000000, "val": 17.57}, {"col": "WS1_50mMean", "idx": 1321347600000, "val": 16.9}, {"col": "WS1_50mMean", "idx": 1321348200000, "val": 14.69}, {"col": "WS1_50mMean", "idx": 1321348800000, "val": 13.59}, {"col": "WS1_50mMean", "idx": 1321349400000, "val": 13.45}, {"col": "WS1_50mMean", "idx": 1321350000000, "val": 14.55}, {"col": "WS1_50mMean", "idx": 1321350600000, "val": 15.86}, {"col": "WS1_50mMean", "idx": 1321351200000, "val": 16.31}, {"col": "WS1_50mMean", "idx": 1321351800000, "val": 16.5}, {"col": "WS1_50mMean", "idx": 1321352400000, "val": 17.65}, {"col": "WS1_50mMean", "idx": 1321353000000, "val": 16.47}, {"col": "WS1_50mMean", "idx": 1321353600000, "val": 15.79}, {"col": "WS1_50mMean", "idx": 1321354200000, "val": 14.49}, {"col": "WS1_50mMean", "idx": 1321354800000, "val": 12.62}, {"col": "WS1_50mMean", "idx": 1321355400000, "val": 10.4}, {"col": "WS1_50mMean", "idx": 1321356000000, "val": 7.0}, {"col": "WS1_50mMean", "idx": 1321356600000, "val": 7.03}, {"col": "WS1_50mMean", "idx": 1321357200000, "val": 7.96}, {"col": "WS1_50mMean", "idx": 1321357800000, "val": 8.07}, {"col": "WS1_50mMean", "idx": 1321358400000, "val": 9.2}, {"col": "WS1_50mMean", "idx": 1321359000000, "val": 8.59}, {"col": "WS1_50mMean", "idx": 1321359600000, "val": 13.29}, {"col": "WS1_50mMean", "idx": 1321360200000, "val": 12.85}, {"col": "WS1_50mMean", "idx": 1321360800000, "val": 13.49}, {"col": "WS1_50mMean", "idx": 1321361400000, "val": 12.66}, {"col": "WS1_50mMean", "idx": 1321362000000, "val": 10.59}, {"col": "WS1_50mMean", "idx": 1321362600000, "val": 8.39}, {"col": "WS1_50mMean", "idx": 1321363200000, "val": 7.77}, {"col": "WS1_50mMean", "idx": 1321363800000, "val": 8.99}, {"col": "WS1_50mMean", "idx": 1321364400000, "val": 11.73}, {"col": "WS1_50mMean", "idx": 1321365000000, "val": 14.06}, {"col": "WS1_50mMean", "idx": 1321365600000, "val": 14.21}, {"col": "WS1_50mMean", "idx": 1321366200000, "val": 15.17}, {"col": "WS1_50mMean", "idx": 1321366800000, "val": 15.09}, {"col": "WS1_50mMean", "idx": 1321367400000, "val": 14.58}, {"col": "WS1_50mMean", "idx": 1321368000000, "val": 14.89}, {"col": "WS1_50mMean", "idx": 1321368600000, "val": 16.75}, {"col": "WS1_50mMean", "idx": 1321369200000, "val": 17.69}, {"col": "WS1_50mMean", "idx": 1321369800000, "val": 18.05}, {"col": "WS1_50mMean", "idx": 1321370400000, "val": 17.1}, {"col": "WS1_50mMean", "idx": 1321371000000, "val": 14.91}, {"col": "WS1_50mMean", "idx": 1321371600000, "val": 15.18}, {"col": "WS1_50mMean", "idx": 1321372200000, "val": 15.35}, {"col": "WS1_50mMean", "idx": 1321372800000, "val": 13.76}, {"col": "WS1_50mMean", "idx": 1321373400000, "val": 12.85}, {"col": "WS1_50mMean", "idx": 1321374000000, "val": 12.16}, {"col": "WS1_50mMean", "idx": 1321374600000, "val": 13.51}, {"col": "WS1_50mMean", "idx": 1321375200000, "val": 14.25}, {"col": "WS1_50mMean", "idx": 13213758 ...

# %%
sb.set_palette('husl')
sb.jointplot('WS1_50mMean', 'WS2_50mMean', data=november_2011, size=9)

# %%
import scipy.stats as stats
plt.figure(figsize=(15, 10))
sb.distplot(ws['WS1_50mMean'], fit=stats.rayleigh)

# %%
(ggplot(aes(x='WS1_50mMean'), data=ws)
 + geom_histogram(fill='#ac4142') 
 + ggtitle("Wind Speed Distribution") 
 + labs("Wind Speed (m)", "Freq"))
# Out:
# binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# <ggplot: (313231469)>

# %%
molten = pd.melt(ws, value_vars=['WS1_50mMean', 'WS2_50mMean', 'WS3_30mMean', 'WS4_40mMean'])
(ggplot(aes(x='value'), data=molten)
 + geom_histogram(fill='#aa759f')
 + facet_wrap('variable')
 + ggtitle("Wind Speed Distribution") 
 + labs("Wind Speed (m)", "Freq"))
# Out:
# binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# <ggplot: (313242201)>

# %%
from IPython.core.display import HTML
styles = open("styles/custom.css", "r").read()
HTML(styles)
# Out:
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Raleway' rel='stylesheet' type='text/css'>
# <style>
#
#   body {
#       font-family: 'Raleway', sans-serif;
#       color: #eff1f5;
#   }
#
#   /*Selectors*/
#
#   div.cell.selected {
#       border: none;
#   }
#
#   div.prompt {
#       display: none;
#   }
#
#   body {background-color:#2b303b;}
#
#   div#maintoolbar, div#header {display: none !important;}
#
#   div#notebook {border-top: none;}
#
#   div.input_area {
#     border-radius: 0px;
#     background-color: #2b303b;
#     border: none;
#   }
#
#   code, pre {
#     font-family: "Source Code Pro";
#   }
#
#   div.output_area pre {font-weight: normal; color: #c0c5ce;}
#
#   .rendered_html table, .rendered_html th, .rendered_html tr, .rendered_html td {
#     border: 1px  #4f5b66 solid;
#     white-space: nowrap;
#   }
#   .rendered_html thead {
#     background-color: #65737e;
#   }
#   .rendered_html th {font-weight: normal;}
#   table.dataframe tr {border: 1px #4f5b66;}
#
#   div.cell.selected {border-radius: 0px;}
#   div.text_cell_render, div.output_html {color: #eff1f5;}
#
#   .highlight .hll {background-color:#2b303b;}
#   .highlight  {background-color:#2b303b;
#                font-family: "Source Code Pro",;
#              }
#   .highlight .c { color: #ab7967; font-style: italic } /* Comment */
#   .highlight .err { border: 1px solid #FF0000 } /* Error */
#   .highlight .k { color: #bf616a;; } /* Keyword */
#   .highlight .o { color: #666666 } /* Operator */
#   .highlight .cm { color: #ab7967; font-style: italic } /* Comment.Multiline */
#   .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
#   .highlight .c1 { color: #ab7967; font-style: italic } /* Comment.Single */
#   .highlight .cs { color: #ab7967; font-style: italic } /* Comment.Special */
#   .highlight .gd { color: #A00000 } /* Generic.Deleted */
#   .highlight .ge { font-style: italic } /* Generic.Emph */
#   .highlight .gr { color: #FF0000 } /* Generic.Error */
#   .highlight .gh { color: #000080; } /* Generic.Heading */
#   .highlight .gi { color: #00A000 } /* Generic.Inserted */
#   .highlight .go { color: #888888 } /* Generic.Output */
#   .highlight .gp { color: #000080; } /* Generic.Prompt */
#   .highlight .gu { color: #800080; } /* Generic.Subheading */
#   .highlight .gt { color: #0044DD } /* Generic.Traceback */
#   .highlight .kc { color: #bf616a; } /* Keyword.Constant */
#   .highlight .kd { color: #bf616a; } /* Keyword.Declaration */
#   .highlight .kn { color: #bf616a; font-weight: normal;} /* Keyword.Namespace */
#   .highlight .kp { color: #bf616a; } /* Keyword.Pseudo */
#   .highlight .kr { color: #bf616a; } /* Keyword.Reserved */
#   .highlight .kt { color: #bf616a; } /* Keyword.Type */
#   .highlight .p { color: #c0c5ce; } /* Brackets */
#   .highlight .o { color: #c0c5ce; } /* =, ., !, etc */
#   .highlight .n { color: #a3be8c; } /* Most text */
#   .highlight .m { color: #b48ead; } /* Literal.Number */
#   .highlight .s { color: #ebcb8b; } /* Literal.String */
#   .highlight .na { color: #a3be8c; } /* Name.Attribute */
#   .highlight .nb { color: #6a9fb5; } /* Name.Builtin */
#   .highlight .nc { color: #a3be8c; } /* Name.Class */
#   .highlight .no { color: #a3be8c;} /* Name.Constant */
#   .highlight .nd { color: #a3be8c; } /* Name.Decorator */
#   .highlight .ni { color: #a3be8c; } /* Name.Entity */
#   .highlight .ne { color: #a3be8c; } /* Name.Exception */
#   .highlight .nf { color: #d08770;} /* Name.Function */
#   .highlight .nl { color: #a3be8c; } /* Name.Label */
#   .highlight .nn { color: #a3be8c; font-weight: normal;} /* Name.Namespace */
#   .highlight .nt { color: #a3be8c; } /* Name.Tag */
#   .highlight .nv { color: #a3be8c; } /* Name.Variable */
#   .highlight .ow { color: #bf616a; } /* Operator.Word */
#   .highlight .w { color: #bbbbbb } /* Text.Whitespace */
#   .highlight .mf { color: #b48ead; } /* Literal.Number.Float */
#   .highlight .mh { color: #b48ead;} /* Literal.Number.Hex */
#   .highlight .mi { color: #b48ead; } /* Literal.Number.Integer */
#   .highlight .mo { color: #b48ead; } /* Literal.Number.Oct */
#   .highlight .sb { color: #ebcb8b; } /* Literal.String.Backtick */
#   .highlight .sc { color: #ebcb8b; } /* Literal.String.Char */
#   .highlight .sd { color: #ebcb8b; font-style: italic } /* Literal.String.Doc */
#   .highlight .s2 { color: #ebcb8b; } /* Literal.String.Double */
#   .highlight .se { color: #ebcb8b; } /* Literal.String.Escape */
#   .highlight .sh { color: #ebcb8b; } /* Literal.String.Heredoc */
#   .highlight .si { color: #ebcb8b; } /* Literal.String.Interpol */
#   .highlight .sx { color: #ebcb8b; } /* Literal.String.Other */
#   .highlight .sr { color: #ebcb8b; } /* Literal.String.Regex */
#   .highlight .s1 { color: #ebcb8b;} /* Literal.String.Single */
#   .highlight .ss { color: #ebcb8b; } /* Literal.String.Symbol */
#   .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
#   .highlight .vc { color: #bf616a; } /* Name.Variable.Class */
#   .highlight .vg { color: #19177C } /* Name.Variable.Global */
#   .highlight .vi { color: #19177C } /* Name.Variable.Instance */
#   .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   .mpld3-xaxis line, .mpld3-yaxis line {
#     stroke: #d0d0d0 !important;
#   }
#   .mpld3-xaxis text, .mpld3-yaxis text, .mpld3-text {
#     fill: #d0d0d0 !important;
#   }
#
# </style>
